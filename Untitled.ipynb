# %%
import pandas as pd
import glob

# %%
# csv_files = glob.glob("movies/*.csv")

# dfs = []
# for file in csv_files:
#     df = pd.read_csv(file)
#     dfs.append(df)
# all_movies = pd.concat(dfs)
# movies = all_movies.drop_duplicates(subset=['movie_name'], keep='first')
# movies = pd.read_csv("movies.csv")

# %%
movies1 = pd.read_csv("combined_movies.csv")

# %%
movies1.head(50)
# Out:
#     Unnamed: 0      id          genre_ids  \
# 0            0     238           [18, 80]
# 1            1     278           [18, 80]
# 2            2     240           [18, 80]
# 3            3     424    [18, 36, 10752]
# 4            4   19404    [35, 18, 10749]
# 5            5     389               [18]
# 6            6     129    [16, 10751, 14]
# 7            7  372058    [10749, 16, 18]
# 8            8  496243       [35, 53, 18]
# 9            9     155   [18, 28, 80, 53]
# 10          10     497       [14, 18, 80]
# 11          11     680           [53, 80]
# 12          12      13    [35, 18, 10749]
# 13          13     122       [12, 14, 28]
# 14          14     429               [37]
# 15          15     769           [18, 80]
# 16          16  569094  [16, 28, 12, 878]
# 17          17   11216        [18, 10749]
# 18          18  667257        [10751, 18]
# 19          19     637           [35, 18]
# 20          20  696374        [10749, 18]
# 21          21     346           [28, 18]
# 22          22   12477    [16, 18, 10752]
# 23          23  772071           [35, 14]
# 24          24     539       [27, 18, 53]
# 25          25     550               [18]
# 26          26  620249       [16, 14, 28]
# 27          27     311           [18, 80]
# 28          28  704264   [28, 12, 16, 18]
# 29          29     598           [18, 80]
# 30          30  724089        [10749, 18]
# 31          31     510               [18]
# 32          32  372754        [10749, 16]
# 33          33   14537       [28, 18, 36]
# 34          34  157336      [12, 18, 878]
# 35          35  820067    [16, 35, 10749]
# 36          36  761053        [10749, 18]
# 37          37  324857  [28, 12, 16, 878]
# 38          38   40096       [35, 18, 14]
# 39          39  378064           [16, 18]
# 40          40     120       [12, 14, 28]
# 41          41    4935       [14, 16, 12]
# 42          42    1891      [12, 28, 878]
# 43          43  255709               [18]
# 44          44     121       [12, 14, 28]
# 45          45     423        [18, 10752]
# 46          46  244786        [18, 10402]
# 47          47   92321    [10749, 16, 14]
# 48          48  930094        [35, 10749]
# 49          49     807     [80, 9648, 53]
#
#                                                 title  \
# 0                                       The Godfather
# 1                            The Shawshank Redemption
# 2                               The Godfather Part II
# 3                                    Schindler's List
# 4                         Dilwale Dulhania Le Jayenge
# 5                                        12 Angry Men
# 6                                       Spirited Away
# 7                                          Your Name.
# 8                                            Parasite
# 9                                     The Dark Knight
# 10                                     The Green Mile
# 11                                       Pulp Fiction
# 12                                       Forrest Gump
# 13      The Lord of the Rings: The Return of the King
# 14                     The Good, the Bad and the Ugly
# 15                                         GoodFellas
# 16                Spider-Man: Across the Spider-Verse
# 17                                    Cinema Paradiso
# 18                                  Impossible Things
# 19                                  Life Is Beautiful
# 20                                  Gabriel's Inferno
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    4999.50000  1.848149e+05     21.545916      6.771740   1673.664300
# std     2886.89568  2.416694e+05     76.294319      0.637059   2890.121954
# min        0.00000  2.000000e+00      0.600000      5.700000    200.000000
# 25%     2499.75000  1.033975e+04      9.118000      6.300000    322.000000
# 50%     4999.50000  3.540850e+04     12.440500      6.700000    611.000000
# 75%     7499.25000  3.476268e+05     19.556500      7.200000   1588.250000
# max     9999.00000  1.140066e+06   4696.546000      8.700000  34262.000000

# %%
shuffled_data = movies.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
movies.shape
# Out:
# (10000, 9)

# %%
reduced_data = shuffled_data.sample(frac=0.40, random_state=42)

# %%
reduced_data.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0      id                genre_ids  \
# 6252        7217  467824        [878, 28, 12, 53]
# 4684        8291    9085             [35, 80, 18]
# 1731        4607  862965             [80, 18, 53]
# 4742        5114  571627         [28, 27, 12, 53]
# 4521        1859   12716                 [12, 18]
# ...          ...     ...                      ...
# 4209        1158   76341            [28, 12, 878]
# 681            8  496243             [35, 53, 18]
# 434         8174  442062  [12, 35, 14, 10751, 27]
# 9309        6996   11625      [10751, 16, 12, 35]
# 4824        8640  309242                 [35, 18]
#
#                                 title  \
# 6252         Illang: The Wolf Brigade
# 4684                    Harlem Nights
# 1731               Emily the Criminal
# 4742                  The Divine Fury
# 4521                My Father's Glory
# ...                               ...
# 4209               Mad Max: Fury Road
# 681                          Parasite
# 434   Goosebumps 2: Haunted Halloween
# 9309        Asterix and the Big Fight
# 4824                Mississippi Grind
#
#                                                overview  popularity  \
# 6252  In 2029, an elite police squad combats an anti...      13.986
# 4684  'Sugar' Ray is the owner of an illegal casino ...      10.312
# 1731  Desperate for income, Emily takes a shady gig ...      43.035
# 4742  After waking up with mysterious wounds on his ...      11.030
# 4521  Raised by his science teacher father, Joseph P...       8.207
# ...                                                 ...         ...
# 4209  An apocalyptic story set in the furthest reach...      54.462
# 681   All unemployed, Ki-taek's family takes peculia...      62.752
# 434   Be careful what you wish for. With their after...      18.013
# 9309  Gaullish custom requires that a would-be chief...       8.998
# 4824  Gerry is a talented but down-on-his-luck gambl...      10.235
#
#      release_date  vote_average  vote_count
# 6252   2018-07-25           6.3         256
# 4684   1989-11-17           6.1         268
# 1731   2022-08-12           6.8         577
# 4742   2019-07-31           6.7         219
# 4521   1990-08-29           7.4         260
# ...           ...           ...         ...
# 4209   2015-05-13           7.6       20783
# 681    2019-05-30           8.5       16210
# 434    2018-10-11           6.1        1342
# 9309   1989-10-04           6.4         540
# 4824   2015-07-04           6.0         429
#
# [4000 rows x 9 columns]>

# %%
import difflib
import numpy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Selecting relevant features for recommendation
selected_features = ['title', 'genre', 'description', 'star', 'director']
print("Selected features:", selected_features)

# Handling missing values by replacing them with an empty string
for feature in selected_features:
    movies[feature] = movies[feature].fillna('')

# Combining selected features into a single feature vector
combined_features = movies['movie_name'] + ' ' + movies['genre'] + ' ' + movies['description'] + ' ' + movies['star'] + ' ' + movies['director']
# Out:
# Selected features: ['movie_name', 'genre', 'description', 'star', 'director']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'movie_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 7
#       5 # Handling missing values by replacing them with an empty string
#       6 for feature in selected_features:
# ----> 7     movies[feature] = movies[feature].fillna('')
#       9 # Combining selected features into a single feature vector
#      10 combined_features = movies['movie_name'] + ' ' + movies['genre'] + ' ' + movies['description'] + ' ' + movies['star'] + ' ' + movies['director']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'movie_name'

# %%
# Converting Text Data to Feature Vectors

# Importing the TfidfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

# Creating an instance of TfidfVectorizer
vectorizer = TfidfVectorizer()

# Converting the combined features into feature vectors
feature_vectors = vectorizer.fit_transform(combined_features)

# Printing the feature vectors
print("Feature vectors:", feature_vectors)

# %%
# Calculating Cosine Similarity

# Importing the cosine_similarity function from scikit-learn
from sklearn.metrics.pairwise import cosine_similarity

# Getting the similarity scores using cosine similarity
similarity = cosine_similarity(feature_vectors)

# Printing the similarity scores
print("Similarity scores:")
print(similarity)

# Printing the shape of the similarity matrix
print("Shape of the similarity matrix:", similarity.shape)

# %%
# Getting Movie Name from User and Finding Close Match

# Importing difflib for string matching
import difflib

# Getting the movie name from the user
movie_name = input('Enter your favorite movie name: ')

# Creating a list with all the movie names given in the dataset
list_of_all_titles = movies_data['title'].tolist()
print("List of all movie titles:")
print(list_of_all_titles)

# Finding the close match for the movie name given by the user
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print("Close match for the movie name:")
print(find_close_match)

# Extracting the closest match
close_match = find_close_match[0]
print("Closest match:", close_match)

# %%
# Finding Similar Movies and Generating Recommendations

# Finding the index of the movie with the closest match title
index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
print("Index of the movie:", index_of_the_movie)

# Getting a list of similar movies based on similarity scores
similarity_score = list(enumerate(similarity[index_of_the_movie]))
print("Similarity scores for similar movies:")
print(similarity_score)

# Sorting the movies based on their similarity score
sorted_similar_movies = sorted(similarity_score, key=lambda x: x[1], reverse=True)
print("Sorted similar movies based on similarity score:")
print(sorted_similar_movies)

# Printing the name of similar movies based on the index
print('Movies suggested for you:')

i = 1

for movie in sorted_similar_movies:
    index = movie[0]
    title_from_index = movies_data[movies_data.index == index]['title'].values[0]
    if i < 30:
        print(i, '.', title_from_index)
        i += 1

# %%
# Prompting the user to enter their favorite movie name
movie_name = input('Enter your favorite movie name: ')

# Creating a list with all the movie titles given in the dataset
list_of_all_titles = movies_data['title'].tolist()

# Finding the close match for the movie name given by the user
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
close_match = find_close_match[0]

# Finding the index of the movie with the closest match title
index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]

# Getting a list of similar movies based on similarity scores
similarity_score = list(enumerate(similarity[index_of_the_movie]))

# Sorting the movies based on their similarity score
sorted_similar_movies = sorted(similarity_score, key=lambda x: x[1], reverse=True)

# Printing the recommended movies for the user
print('Movies suggested for you:')

i = 1
for movie in sorted_similar_movies:
    index = movie[0]
    title_from_index = movies_data[movies_data.index == index]['title'].values[0]
    if i < 30:
        print(i, '.', title_from_index)
        i += 1
